# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
import csv
from tqdm import tqdm
import json

# %%
qwen2VL = Qwen2VLForConditionalGeneration.from_pretrained("Qwen/Qwen2-VL-7B-Instruct", device_map="auto")
qwen_processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
def qwen2vl_text_only_gen(question):
    conversation = [
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": question
                }
            ]
        }
    ]
    
    # Preprocess the inputs
    text_prompt = qwen_processor.apply_chat_template(conversation, add_generation_prompt=True)
    
    inputs = qwen_processor(text=[text_prompt], images=None, padding=True, return_tensors="pt")
    inputs = inputs.to('cuda')
    
    # Use sampling instead of deterministic generation
    output_ids = qwen2VL.generate(
        **inputs, 
        max_new_tokens=64, 
        do_sample=True, 
        top_k=50, 
        top_p=0.9,  # Adjust for more diversity
        temperature=0.8  # Increase randomness
    )
    generated_ids = [output_ids[len(input_ids):] for input_ids, output_ids in zip(inputs.input_ids, output_ids)]
    output_text = qwen_processor.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True)
    return output_text[0]

# %%
import json
from tqdm import tqdm

output_file = "prompts.json"
objects_file = "interesting_objects_v3.txt"
gen_types = ["easy", "medium", "hard"]

base_prompts = {
    "easy": "Generate a very short prompt for an image that includes the given object. Generate the prompt and nothing else. Object: {obj}. Prompt:",
    "medium": "Generate a description for an image that includes the given object along with other objects that can be with it. Generate the prompt and nothing else. Object: {obj}. Prompt:",
    "hard": "Generate a prompt for a surreal or imaginary scenario for an image that includes the given object. Generate the prompt and nothing else. Object: {obj}. Prompt:",
}

# Read objects from file
with open(objects_file, "r") as f:
    objects = [o.strip() for o in f.readlines()]

# Dictionary to store generated prompts
prompts_dict = {}

# Process objects with tqdm progress bar
for obj in tqdm(objects, desc="Generating Prompts", unit="obj"):
    prompts_dict[obj] = []
    
    for prompt_type, prompt in base_prompts.items():
        formatted_prompt = prompt.format(obj=obj)
        generated_prompt = qwen2vl_text_only_gen(formatted_prompt)
        
        # Store prompt type along with the generated text
        prompts_dict[obj].append({
            "type": prompt_type,
            "text": generated_prompt.replace('"', "")
        })

    # Save to JSON file after all prompts are generated
    with open(output_file, "w") as jsonfile:
        json.dump(prompts_dict, jsonfile, indent=4)

print("All prompts generated and saved successfully!")
# Out:
# Generating Prompts: 100%|██████████| 159/159 [07:52<00:00,  2.97s/obj]
# All prompts generated and saved successfully!

# %%
import json

# File containing the generated prompts
output_file = "prompts.json"

# Load the JSON data
with open(output_file, "r") as jsonfile:
    prompts_dict = json.load(jsonfile)

# Print the full dictionary
print(json.dumps(prompts_dict, indent=4))
# Out:
# {
#     "food": [
#         {
#             "type": "easy",
#             "text": "A plate of food sits on a table, inviting someone to indulge in a delicious meal."
#         },
#         {
#             "type": "medium",
#             "text": "A plate of delicious food with a fork and knife on the side."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike landscape, a floating, glowing hamburger with a sizzling patty and dripping condiments dances in the air, surrounded by shimmering, liquid-like vegetables and fruits."
#         }
#     ],
#     "part": [
#         {
#             "type": "easy",
#             "text": "Close-up shot of a metal part in a workshop."
#         },
#         {
#             "type": "medium",
#             "text": "A part of a larger object surrounded by various tools and materials for assembly or repair."
#         },
#         {
#             "type": "hard",
#             "text": "A part of a human body, floating in a dreamscape, surrounded by vibrant colors and strange creatures."
#         }
#     ],
#     "location": [
#         {
#             "type": "easy",
#             "text": "Explore the stunning location with breathtaking views and lush greenery."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy living room with a comfortable couch, a coffee table, and a bookshelf filled with various books."
#         },
#         {
#             "type": "hard",
#             "text": "A person walks through a dense forest, only to find themselves in a completely surreal location where the trees are made of ice and the ground is covered in snow, but the sky is a vivid shade of orange, creating an otherworldly atmosphere."
#         }
#     ],
#     "body": [
#         {
#             "type": "easy",
#             "text": "A person's body in motion."
#         },
#         {
#             "type": "medium",
#             "text": "A person's body is adorned with a beautiful necklace, with a ring on their finger and a bracelet on their wrist, surrounded by a garden of blooming flowers and a clear blue sky."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal scene where a person's body is made entirely of liquid, flowing and changing shape with each breath."
#         }
#     ],
#     "way": [
#         {
#             "type": "easy",
#             "text": "A way leads through the forest."
#         },
#         {
#             "type": "medium",
#             "text": "A winding road surrounded by lush greenery, with a stream flowing alongside it."
#         },
#         {
#             "type": "hard",
#             "text": "In a surreal world, a way leads to a place where time stands still, and the sky is filled with colorful, iridescent birds."
#         }
#     ],
#     "ground": [
#         {
#             "type": "easy",
#             "text": "View of the ground from a high vantage point."
#         },
#         {
#             "type": "medium",
#             "text": "A ground with a beautiful landscape, surrounded by trees and hills, with a stream flowing through it."
#         },
#         {
#             "type": "hard",
#             "text": "A ground that glows with a soft, otherworldly light, stretching out as far as the eye can see, with strange, undulating hills and valleys that shift and change in the blink of an eye."
#         }
#     ],
#     "surface": [
#         {
#             "type": "easy",
#             "text": "The surface of the table is smooth and polished."
#         },
#         {
#             "type": "medium",
#             "text": "A glass surface reflecting a blue sky and white clouds."
#         },
#         {
#             "type": "hard",
#             "text": "A person floating on a surface of liquid glass, unable to touch the ground, surrounded by a kaleidoscope of colors and patterns reflecting off the surface."
#         }
#     ],
#     "bed": [
#         {
#             "type": "easy",
#             "text": "A cozy bed with soft pillows and blankets."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy bed with plush pillows and a soft blanket surrounded by a warm, inviting bedroom with soft lighting and a large window with a view of a tranquil garden."
#         },
#         {
#             "type": "hard",
#             "text": "In the middle of a bustling city, a bed floats in mid-air above a busy street, with its sheets billowing in the wind."
#         }
#     ],
#     "process": [
#         {
#             "type": "easy",
#             "text": "A detailed illustration of a complex machine in the process of operation."
#         },
#         {
#             "type": "medium",
#             "text": "A scientist is carefully monitoring the progress of a chemical process in a laboratory, surrounded by beakers, test tubes, and other scientific equipment."
#         },
#         {
#             "type": "hard",
#             "text": "A group of humans, each with a different job in the process of making a cup of coffee, are all connected by a single, endless conveyor belt that loops around the world."
#         }
#     ],
#     "center": [
#         {
#             "type": "easy",
#             "text": "A person standing in the center of a room."
#         },
#         {
#             "type": "medium",
#             "text": "A statue of a woman with a dog at the center of a park."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape with a towering center stone that seemingly floats in the air, surrounded by swirling mist and strange, otherworldly creatures."
#         }
#     ],
#     "head": [
#         {
#             "type": "easy",
#             "text": "A person's head with short, brown hair."
#         },
#         {
#             "type": "medium",
#             "text": "A person's head, with hair, a forehead, eyebrows, and eyes, is adorned with a headband and surrounded by a warm, cozy room."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal image featuring a person with a head that is constantly spinning in circles, causing the surrounding world to shift and blur."
#         }
#     ],
#     "glasses": [
#         {
#             "type": "easy",
#             "text": "A pair of glasses resting on a wooden table."
#         },
#         {
#             "type": "medium",
#             "text": "A person wearing glasses is holding a cup of coffee in one hand and a book in the other."
#         },
#         {
#             "type": "hard",
#             "text": "A woman in a dress of feathers and flowers stands in a room made entirely of books. She is wearing glasses made of crystal, which shimmer and catch the light in an otherworldly way. As she looks out the window, the room begins to shift and twist, the walls and ceiling turning into intricate patterns of lace"
#         }
#     ],
#     "element": [
#         {
#             "type": "easy",
#             "text": "An element in its purest form, shining brightly and untouched by human hands."
#         },
#         {
#             "type": "medium",
#             "text": "An element, surrounded by a circle of colorful, glowing orbs, with a shimmering star in the background."
#         },
#         {
#             "type": "hard",
#             "text": "A man floating in the sky, made entirely of the element air, gazing up at the sun."
#         }
#     ],
#     "weight": [
#         {
#             "type": "easy",
#             "text": "A scale with a weight on it."
#         },
#         {
#             "type": "medium",
#             "text": "A person holding a weight in their hands, surrounded by a gym setting with weights and exercise equipment in the background."
#         },
#         {
#             "type": "hard",
#             "text": "A weightless world where objects float and the only force holding them together is the power of imagination."
#         }
#     ],
#     "vehicle": [
#         {
#             "type": "easy",
#             "text": "A vehicle in motion on a road."
#         },
#         {
#             "type": "medium",
#             "text": "A vehicle is parked on a busy street with a bustling city in the background."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where vehicles can think and feel, a group of sentient cars band together to rebel against their human drivers and take over the world. As they ride through the streets, their colorful lights flicker and hum with a life of their own."
#         }
#     ],
#     "growth": [
#         {
#             "type": "easy",
#             "text": "A small plant with green leaves growing out of the soil."
#         },
#         {
#             "type": "medium",
#             "text": "A young tree with green leaves and a healthy trunk is surrounded by a patch of soil with seeds waiting to sprout."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal garden where plants grow in the shape of human faces."
#         }
#     ],
#     "wall": [
#         {
#             "type": "easy",
#             "text": "A tall, white wall stands against a blue sky."
#         },
#         {
#             "type": "medium",
#             "text": "A wall painted in a vibrant shade of blue, with a few framed pictures hanging on it, including a photograph of a bustling cityscape and a canvas painting of a serene beach scene."
#         },
#         {
#             "type": "hard",
#             "text": "A wall made of glowing, multicolored crystals that seems to shimmer and change shape in the flickering light of a distant fire."
#         }
#     ],
#     "curiosity": [
#         {
#             "type": "easy",
#             "text": "A small yellow cat with big ears, wide eyes, and a long nose peers into the camera with curiosity."
#         },
#         {
#             "type": "medium",
#             "text": "A curious cat peers around a corner, surrounded by scattered toys and a cozy blanket."
#         },
#         {
#             "type": "hard",
#             "text": "A curious rabbit wearing a top hat and monocle sits on a magic carpet, floating above a mysterious, glowing forest."
#         }
#     ],
#     "structure": [
#         {
#             "type": "easy",
#             "text": "A towering structure reaches towards the sky, its intricate design showcasing a marvel of human engineering."
#         },
#         {
#             "type": "medium",
#             "text": "A complex architectural structure stands tall against the backdrop of a bustling cityscape, surrounded by towering skyscrapers and bustling streets."
#         },
#         {
#             "type": "hard",
#             "text": "A towering structure made of shimmering, iridescent petals reaches towards the sky, its intricate patterns and vibrant colors reminiscent of a kaleidoscope."
#         }
#     ],
#     "glass": [
#         {
#             "type": "easy",
#             "text": "A glass of water on a table."
#         },
#         {
#             "type": "medium",
#             "text": "A crystal-clear glass of water sits on a polished wooden table, surrounded by golden-brown bread rolls and a stack of pristine white plates."
#         },
#         {
#             "type": "hard",
#             "text": "A glass with a face, sitting at a table, holding a spoon."
#         }
#     ],
#     "ways": [
#         {
#             "type": "easy",
#             "text": "Explore the various ways to travel around the world."
#         },
#         {
#             "type": "medium",
#             "text": "A person walking down a path surrounded by trees and rocks, with a backpack and hiking poles in hand."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where time and space are fluid, a group of travelers journey through various dimensions, each one filled with ways that lead to different outcomes. From the twisted paths of a forest where time stands still, to the endless plains of a desert where the sun never sets, each way is a journey to a new world"
#         }
#     ],
#     "decker": [
#         {
#             "type": "easy",
#             "text": "A decker in a crowded room, surrounded by people and noise."
#         },
#         {
#             "type": "medium",
#             "text": "Deck of cards with a decker."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike forest, a decker dances among the towering trees, its sleek body glowing with an ethereal light that dances across the trunks. The decker's movements are fluid and graceful, as if it is a part of the very forest itself. The air is thick with the scent of pine and wild"
#         }
#     ],
#     "object": [
#         {
#             "type": "easy",
#             "text": "A lone object stands in the center of an empty room."
#         },
#         {
#             "type": "medium",
#             "text": "A vibrant red apple sits on a wooden table, surrounded by a basket of fresh flowers and a stack of books."
#         },
#         {
#             "type": "hard",
#             "text": "A mysterious object, with a glowing, iridescent surface, floats weightlessly in a dreamy, otherworldly landscape of floating clouds and ethereal mountains."
#         }
#     ],
#     "portion": [
#         {
#             "type": "easy",
#             "text": "A delicious portion of cake on a plate."
#         },
#         {
#             "type": "medium",
#             "text": "A portion of food on a plate, accompanied by a fork and a napkin."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where everything is split into portions, a giant portion of cake stands on a table, with tiny portions of people surrounding it, trying to get a bite."
#         }
#     ],
#     "lot": [
#         {
#             "type": "easy",
#             "text": "A large pile of something."
#         },
#         {
#             "type": "medium",
#             "text": "A vast expanse of water with a calm surface, surrounded by lush greenery and mountains in the distance."
#         },
#         {
#             "type": "hard",
#             "text": "A lot of lotus flowers bloomed on the surface of a shimmering, iridescent pond, their petals floating like miniature clouds."
#         }
#     ],
#     "challenge": [
#         {
#             "type": "easy",
#             "text": "A challenge awaits you in this image."
#         },
#         {
#             "type": "medium",
#             "text": "A person standing in front of a challenging mountain with a backpack and hiking poles, surrounded by trees and a cloudy sky."
#         },
#         {
#             "type": "hard",
#             "text": "A person stands on the edge of a precipice, holding a single, glowing challenge coin, as if daring fate to take their hand."
#         }
#     ],
#     "track": [
#         {
#             "type": "easy",
#             "text": "A lone runner on a track."
#         },
#         {
#             "type": "medium",
#             "text": "A person running on a track surrounded by a trackside barrier, a trackside sign, and a trackside camera."
#         },
#         {
#             "type": "hard",
#             "text": "A track of tiny, iridescent insects twists and turns through a dense, otherworldly forest, their delicate wings catching the light in a mesmerizing display."
#         }
#     ],
#     "goods": [
#         {
#             "type": "easy",
#             "text": "Stack of goods for sale at a market."
#         },
#         {
#             "type": "medium",
#             "text": "A market stall selling a variety of goods, including fruits, vegetables, and clothing."
#         },
#         {
#             "type": "hard",
#             "text": "A grocery store aisle is filled with towering shelves of goods, but instead of food items, the shelves are stocked with strange and bizarre objects - a giant teddy bear, a stack of old books, a pile of rocks, a pile of feathers, and more."
#         }
#     ],
#     "material": [
#         {
#             "type": "easy",
#             "text": "Material: The texture and weight of the object are the focal point of this image."
#         },
#         {
#             "type": "medium",
#             "text": "A material, such as fabric, can be used to create a variety of items, including clothing, furniture, and accessories. It can be combined with other materials, such as wood, metal, or plastic, to create a range of products for different purposes. For example, a material like leather can be used to make"
#         },
#         {
#             "type": "hard",
#             "text": "In a world where everything is made of material, a shimmering, iridescent butterfly flutters gracefully, its wings made of intricate patterns of metal and glass that reflect the colors of the rainbow."
#         }
#     ],
#     "property": [
#         {
#             "type": "easy",
#             "text": "A cozy property with a charming garden in the background."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy living room featuring a plush sofa, a wooden coffee table, and a large window with a scenic view."
#         },
#         {
#             "type": "hard",
#             "text": "A group of children play in a field of towering trees, each with a unique property that makes them unlike any other. The tree with the property of being able to speak in a language only children can understand stands out from the rest."
#         }
#     ],
#     "fuel": [
#         {
#             "type": "easy",
#             "text": "A fuel tank with a hose attached to it."
#         },
#         {
#             "type": "medium",
#             "text": "A fuel tank is filled with gasoline, ready for a long road trip. The tank is located in the back of a vintage car, surrounded by the warm glow of the setting sun. The driver is about to embark on a journey across the country, with the promise of endless possibilities ahead."
#         },
#         {
#             "type": "hard",
#             "text": "A fuel station where cars are fueled by dream fuel, which fills them with vivid and surreal dreams as they drive off into the distance."
#         }
#     ],
#     "construction": [
#         {
#             "type": "easy",
#             "text": "A construction site with heavy machinery and workers in hard hats."
#         },
#         {
#             "type": "medium",
#             "text": "A bustling construction site filled with workers, cranes, and machinery, surrounded by a fence and construction materials scattered across the ground."
#         },
#         {
#             "type": "hard",
#             "text": "A construction site transforms into a fantastical wonderland, with towering skyscrapers adorned with colorful, floating balloons and playful animals made of metal and concrete."
#         }
#     ],
#     "layer": [
#         {
#             "type": "easy",
#             "text": "A layered cake with multiple layers of buttercream frosting."
#         },
#         {
#             "type": "medium",
#             "text": "A layered cake with frosting and sprinkles."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where layers of reality can be peeled away like an onion, a lone traveler stands at the edge of a vast expanse of land, revealing a layer upon layer of hidden worlds beneath their feet."
#         }
#     ],
#     "land": [
#         {
#             "type": "easy",
#             "text": "A vast, green landscape stretches out before you, with rolling hills and lush forests as far as the eye can see."
#         },
#         {
#             "type": "medium",
#             "text": "A vast expanse of land stretches out before you, with rolling hills and a winding river cutting through it. The sky is a deep blue, with wispy clouds drifting overhead."
#         },
#         {
#             "type": "hard",
#             "text": "A vast, endless land of shifting sands and towering dunes, where the sun beats down with an unrelenting heat and the air is thick with the scent of sand and salt. The horizon stretches out as far as the eye can see, dotted with strange and otherworldly formations of rock and stone, while strange"
#         }
#     ],
#     "media": [
#         {
#             "type": "easy",
#             "text": "A television screen broadcasting a news program."
#         },
#         {
#             "type": "medium",
#             "text": "A media player with a remote control and headphones nearby."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where technology and media have taken over, a man finds himself trapped inside a glowing TV screen, his body transformed into a digital entity, surrounded by a world of holographic advertisements and streaming content."
#         }
#     ],
#     "decoration": [
#         {
#             "type": "easy",
#             "text": "A beautifully decorated tree with sparkling lights and colorful ornaments."
#         },
#         {
#             "type": "medium",
#             "text": "A beautifully decorated room with elegant furniture and intricate decorations, including floral arrangements, ornate vases, and sparkling chandeliers."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal scene featuring a giant, glowing, iridescent decoration that appears to be made of rainbow-colored feathers, floating in the sky above a whimsical, dreamlike landscape filled with floating islands, giant flowers, and talking animals."
#         }
#     ],
#     "facility": [
#         {
#             "type": "easy",
#             "text": "A modern facility with state-of-the-art equipment and spacious rooms."
#         },
#         {
#             "type": "medium",
#             "text": "A modern facility with state-of-the-art equipment, surrounded by lush greenery and a clear blue sky in the background."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where facilities are alive and sentient, a massive, towering structure stands as the heart of a bustling city. Its metallic frame gleams under the harsh light of the sun, and its intricate network of pipes and ducts hum with a life force all its own. As the shadows lengthen and the sky dark"
#         }
#     ],
#     "nutrient": [
#         {
#             "type": "easy",
#             "text": "A nutrient-rich plant in a garden."
#         },
#         {
#             "type": "medium",
#             "text": "A nutrient-rich meal consisting of leafy greens, whole grains, and lean protein sources."
#         },
#         {
#             "type": "hard",
#             "text": "A person made entirely of nutrient powder floats weightlessly in a space station, their body shimmering with a nutrient-rich glow."
#         }
#     ],
#     "passion": [
#         {
#             "type": "easy",
#             "text": "A vibrant flower in full bloom, radiating a sense of intense passion."
#         },
#         {
#             "type": "medium",
#             "text": "A person holding a bouquet of vibrant flowers, their face lit up with a radiant smile as they bask in the warmth of the sun, surrounded by a gentle breeze that carries the sweet scent of the blossoms."
#         },
#         {
#             "type": "hard",
#             "text": "A passionate red rose with fiery wings flies through a kaleidoscope of colors, its petals swirling in a whirlwind of emotion."
#         }
#     ],
#     "charm": [
#         {
#             "type": "easy",
#             "text": "A bracelet with a small, heart-shaped charm dangles from a delicate wrist."
#         },
#         {
#             "type": "medium",
#             "text": "A charm bracelet adorned with various beads and pendants sits gracefully on a soft, cushioned surface, surrounded by an array of delicate, sparkling jewelry and a bouquet of fresh, fragrant flowers."
#         },
#         {
#             "type": "hard",
#             "text": "A person holds a charm in their hand, which glows with an otherworldly light and seems to transport them to a fantastical realm."
#         }
#     ],
#     "soil": [
#         {
#             "type": "easy",
#             "text": "A small green plant growing out of brown soil."
#         },
#         {
#             "type": "medium",
#             "text": "A patch of soil surrounded by green grass and blooming flowers."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape of floating islands made entirely of soil, with swirling clouds of dust and a sun that appears to be made of cake crumbs."
#         }
#     ],
#     "formation": [
#         {
#             "type": "easy",
#             "text": "An abstract formation of light and shadows in a dark room."
#         },
#         {
#             "type": "medium",
#             "text": "A majestic mountain formation rises into the sky, surrounded by a lush forest of tall trees and cascading waterfalls."
#         },
#         {
#             "type": "hard",
#             "text": "A group of trees grow in the shape of a heart, with their branches forming the sides and leaves the petals, standing in a field of wildflowers that seem to ripple like water."
#         }
#     ],
#     "cause": [
#         {
#             "type": "easy",
#             "text": "Create a prompt for an image that includes the object 'cause.'"
#         },
#         {
#             "type": "medium",
#             "text": "A cause can be associated with a group of people, a campaign, and a goal."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where causes have the power to bend reality, a woman stands on the edge of a swirling vortex, her hand outstretched towards a floating, glowing orb labeled Cause."
#         }
#     ],
#     "trash": [
#         {
#             "type": "easy",
#             "text": "A pile of trash on the ground."
#         },
#         {
#             "type": "medium",
#             "text": "Trash can filled with various items, including paper, plastic bottles, and food waste."
#         },
#         {
#             "type": "hard",
#             "text": "A group of people stand on a beach, surrounded by piles of trash, as a strange, glowing creature emerges from the sea."
#         }
#     ],
#     "milk": [
#         {
#             "type": "easy",
#             "text": "A glass of milk with a small bottle of milk on a table."
#         },
#         {
#             "type": "medium",
#             "text": "A glass of milk sits on a wooden table surrounded by fresh fruit and a stack of books."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where milk is a rare commodity, a young girl discovers a magical cow that can produce an endless supply of fresh milk, but only if she can solve a series of riddles and puzzles that unlock its hidden potential. As she embarks on her journey, she encounters strange creatures, solves mind-bending puzzles"
#         }
#     ],
#     "world": [
#         {
#             "type": "easy",
#             "text": "The world is vast and full of wonder, waiting to be explored and understood."
#         },
#         {
#             "type": "medium",
#             "text": "A diverse array of objects can be found throughout the world, from bustling cities to serene landscapes, each with their own unique charm and beauty."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where the sky is a kaleidoscope of colors and the ground is covered in shimmering sequins, a young girl with a world map tattooed on her arm navigates through a labyrinth of towering skyscrapers that seem to stretch up to the clouds."
#         }
#     ],
#     "blood": [
#         {
#             "type": "easy",
#             "text": "A drop of blood on a white background."
#         },
#         {
#             "type": "medium",
#             "text": "A medical glove lies on a table next to a blood sample tube."
#         },
#         {
#             "type": "hard",
#             "text": "A blood-colored sunset casts a surreal glow over a barren landscape, where a lone figure stumbles through the desolate terrain, their footsteps crunching on the dry, cracked earth."
#         }
#     ],
#     "mixture": [
#         {
#             "type": "easy",
#             "text": "A bowl filled with a colorful mixture of ingredients."
#         },
#         {
#             "type": "medium",
#             "text": "A mixture of colorful ingredients being stirred together in a bowl."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where colors are made of liquid, a group of adventurers embark on a quest to find the source of the world's most vibrant mixture. Along their journey, they encounter strange creatures and navigate treacherous landscapes, all in pursuit of the elusive mixture that holds the key to unlocking the true potential of their world"
#         }
#     ],
#     "line": [
#         {
#             "type": "easy",
#             "text": "An abstract image featuring a single, straight line."
#         },
#         {
#             "type": "medium",
#             "text": "A straight line drawn in the sky with a kite flying nearby."
#         },
#         {
#             "type": "hard",
#             "text": "A line stretches out into infinity, weaving its way through a dreamlike landscape of abstract shapes and colors. The line appears to have a life of its own, constantly changing shape and direction as it moves through the surreal scene. As the viewer's gaze follows the line, they feel as though they are being pulled deeper into"
#         }
#     ],
#     "essence": [
#         {
#             "type": "easy",
#             "text": "A bottle of essential oil with a dropper, capturing the essence of a fragrant plant."
#         },
#         {
#             "type": "medium",
#             "text": "A bottle of essential oil surrounded by flowers and a candle."
#         },
#         {
#             "type": "hard",
#             "text": "A droplet of essence floats in a dreamy, ethereal space, surrounded by swirling colors and shapes that seem to pulse with life."
#         }
#     ],
#     "juice": [
#         {
#             "type": "easy",
#             "text": "A glass of freshly squeezed orange juice."
#         },
#         {
#             "type": "medium",
#             "text": "A glass of freshly squeezed orange juice sits on a wooden table next to a bunch of ripe oranges and a bottle of honey."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where juice is a rare and valuable resource, a group of adventurers embark on a perilous journey to find the fabled Juice Tree, said to be the only source of fresh juice in the land."
#         }
#     ],
#     "installation": [
#         {
#             "type": "easy",
#             "text": "Installation art piece with geometric shapes and vibrant colors."
#         },
#         {
#             "type": "medium",
#             "text": "A modern art installation featuring geometric shapes and vibrant colors surrounded by a group of onlookers."
#         },
#         {
#             "type": "hard",
#             "text": "An abandoned, dilapidated building is slowly being overtaken by a surreal installation of floating, glowing objects that seem to defy gravity and logic, creating a bizarre and eerie atmosphere."
#         }
#     ],
#     "toy": [
#         {
#             "type": "easy",
#             "text": "A colorful toy lies on a wooden floor."
#         },
#         {
#             "type": "medium",
#             "text": "A toy can be found in a variety of settings, from a child's bedroom to a toy store. It can be a simple building block or a complex action figure, and it can be accompanied by other toys, such as a stuffed animal or a set of action figures."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal image of a giant toy elephant wandering through a small, crowded city street, surrounded by tiny people who are either admiring or avoiding it."
#         }
#     ],
#     "cement": [
#         {
#             "type": "easy",
#             "text": "A construction site with a large cement mixer."
#         },
#         {
#             "type": "medium",
#             "text": "A construction site with a large cement mixer and a worker wearing a hard hat."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where cement has come to life, a giant cement hand reaches out from the sky, its fingers splaying wide to grasp the earth beneath. As it descends, the ground shakes beneath the weight of its touch, and the air crackles with the sound of cracking and crumbling. The cement hand moves slowly"
#         }
#     ],
#     "humor": [
#         {
#             "type": "easy",
#             "text": "A cartoon cat holding a sign that says Why did the tomato turn red?"
#         },
#         {
#             "type": "medium",
#             "text": "A humorous cartoon cat, surrounded by a group of laughing children, sits on a couch in front of a TV showing a funny movie."
#         },
#         {
#             "type": "hard",
#             "text": "A holographic elephant wearing a tie and holding a cocktail glass, surrounded by floating laughter clouds."
#         }
#     ],
#     "love": [
#         {
#             "type": "easy",
#             "text": "A heart filled with love."
#         },
#         {
#             "type": "medium",
#             "text": "A heart-shaped balloon filled with love floats among vibrant flowers and a picturesque landscape."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape where love blooms in the form of glowing, ethereal flowers that emit a soft, warm glow, attracting butterflies and other magical creatures."
#         }
#     ],
#     "pavement": [
#         {
#             "type": "easy",
#             "text": "The sun casts shadows on the cracked pavement."
#         },
#         {
#             "type": "medium",
#             "text": "A bustling city street lined with tall buildings, where the pavement is worn and cracked, with patches of grass growing through."
#         },
#         {
#             "type": "hard",
#             "text": "A pavement made of sparkling diamonds stretches out into the distance, leading to a hidden cave of glittering jewels."
#         }
#     ],
#     "matter": [
#         {
#             "type": "easy",
#             "text": "A pile of matter."
#         },
#         {
#             "type": "medium",
#             "text": "A matter of fact, the world is full of matter in various forms, such as solid, liquid, and gas, and it is the building block of all physical things."
#         },
#         {
#             "type": "hard",
#             "text": "A man made of pure matter stood in the center of a room, his body shimmering with a faint glow. The walls of the room were made of a strange, translucent material that seemed to merge with the very air itself. The floor was a bed of golden sand, and the ceiling was a vast expanse of"
#         }
#     ],
#     "ice": [
#         {
#             "type": "easy",
#             "text": "A crystal-clear ice cube glinting in the sunlight."
#         },
#         {
#             "type": "medium",
#             "text": "A crystal-clear ice cube glinting in the sunlight, accompanied by a refreshing slice of lemon and a sprig of mint for a perfect summer cocktail."
#         },
#         {
#             "type": "hard",
#             "text": "A massive, crystalline structure rises from the ocean floor, its jagged edges glistening like a frozen wave."
#         }
#     ],
#     "thing": [
#         {
#             "type": "easy",
#             "text": "A small, shiny object with intricate details."
#         },
#         {
#             "type": "medium",
#             "text": "A thing, a lamp, a book, and a cup."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike world, a mysterious thing glows with an ethereal light, casting an otherworldly aura around it as it\u6f02\u6d6e in a serene, otherworldly landscape."
#         }
#     ],
#     "lots": [
#         {
#             "type": "easy",
#             "text": "An abundance of something."
#         },
#         {
#             "type": "medium",
#             "text": "A bustling city street filled with lots of people, cars, and buildings."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike landscape, a towering mountain of glittering gemstones rises into the sky, each one sparkling with an otherworldly glow. The air is thick with the scent of exotic flowers, and a chorus of birdsong echoes through the valley below. In the distance, a herd of unicorns grazes peacefully"
#         }
#     ],
#     "beef": [
#         {
#             "type": "easy",
#             "text": "A delicious steak sizzling on a grill."
#         },
#         {
#             "type": "medium",
#             "text": "A juicy piece of beef sits on a plate next to a fresh salad and a glass of red wine."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike landscape, a giant beef steak floats gracefully in the sky, surrounded by floating vegetables and fruits."
#         }
#     ],
#     "catch": [
#         {
#             "type": "easy",
#             "text": "A person is catching a baseball in mid-air."
#         },
#         {
#             "type": "medium",
#             "text": "A person catching a baseball with a glove on their hand."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike world, a young girl catches a golden butterfly with a net made of rainbow threads. As she holds it gently, the butterfly transforms into a small dragon with wings of fire. The girl watches in awe as the dragon soars into the sky, leaving behind a trail of sparkles."
#         }
#     ],
#     "creation": [
#         {
#             "type": "easy",
#             "text": "A beautiful, vibrant garden filled with blooming flowers and lush greenery, symbolizing the beauty and wonder of creation."
#         },
#         {
#             "type": "medium",
#             "text": "A newborn baby surrounded by a loving family, with a backdrop of a beautiful garden and a rainbow in the sky."
#         },
#         {
#             "type": "hard",
#             "text": "A group of children stand around a large, glowing sphere, their faces lit up with wonder as they watch the spinning wheel of creation."
#         }
#     ],
#     "prop": [
#         {
#             "type": "easy",
#             "text": "A prop in a museum exhibit."
#         },
#         {
#             "type": "medium",
#             "text": "An antique prop sits on a wooden table next to a stack of old books and a vintage camera."
#         },
#         {
#             "type": "hard",
#             "text": "A propeller floats in mid-air, surrounded by an otherworldly, colorful mist."
#         }
#     ],
#     "cones": [
#         {
#             "type": "easy",
#             "text": "Red and yellow ice cream cones against a blue sky."
#         },
#         {
#             "type": "medium",
#             "text": "A vibrant scene with colorful cones, scattered around a lush green field, with a blue sky in the background."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape where the ground is covered in an endless expanse of ice cream cones, their vibrant colors and flavors contrasting against the cold surroundings."
#         }
#     ],
#     "cloth": [
#         {
#             "type": "easy",
#             "text": "A piece of cloth hanging on a clothesline."
#         },
#         {
#             "type": "medium",
#             "text": "A pile of clothes, including shirts, pants, and socks, sits on a table next to a basket of laundry and a laundry detergent bottle."
#         },
#         {
#             "type": "hard",
#             "text": "A cloth of pure, shimmering silver draped over a majestic unicorn, with the sun's rays reflecting off its surface in a mesmerizing display of light and color."
#         }
#     ],
#     "padding": [
#         {
#             "type": "easy",
#             "text": "An image of a pile of soft, fluffy pillows and cushions, with a thick, plush blanket draping over the edge, creating a cozy and inviting atmosphere."
#         },
#         {
#             "type": "medium",
#             "text": "A tablet with a blue case and a white keyboard on a wooden table."
#         },
#         {
#             "type": "hard",
#             "text": "A giant, fluffy, white cat with a round, plush body and a long, tail-like tail, wearing a cozy, blue sweater with a yellow and orange striped collar, padding through a dreamy, enchanted forest with trees that are adorned with glowing, rainbow-colored leaves and a crystal-clear stream that sparkles in the"
#         }
#     ],
#     "mechanism": [
#         {
#             "type": "easy",
#             "text": "A intricate mechanism with gears and cogs whirring to life."
#         },
#         {
#             "type": "medium",
#             "text": "A complex mechanical device with gears and levers, surrounded by a variety of tools and parts."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where time is not linear and space is fluid, a mechanism made of swirling gears and glowing crystals stands as a testament to the power of imagination and the boundless potential of the human mind."
#         }
#     ],
#     "stuff": [
#         {
#             "type": "easy",
#             "text": "A cluttered room filled with various objects and items, creating a sense of disorganization and disarray."
#         },
#         {
#             "type": "medium",
#             "text": "A pile of stuff, including books, clothes, and electronics, sits on a cluttered desk."
#         },
#         {
#             "type": "hard",
#             "text": "A room filled with an endless assortment of everyday objects, each one completely out of place and out of context, creating a surreal and imaginary scene."
#         }
#     ],
#     "kick": [
#         {
#             "type": "easy",
#             "text": "A person kicking a soccer ball."
#         },
#         {
#             "type": "medium",
#             "text": "A person is kicking a soccer ball on a green field."
#         },
#         {
#             "type": "hard",
#             "text": "A kickboxing match in a surreal world where the fighters are giant ants and the arena is a towering mushroom."
#         }
#     ],
#     "grounds": [
#         {
#             "type": "easy",
#             "text": "The grounds of the park were covered in green grass."
#         },
#         {
#             "type": "medium",
#             "text": "A lush green landscape with a sprawling field, where wildflowers bloom and the wind rustles the grass."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape unfolds as the viewer gazes upon a vast expanse of grounds, where the earth is covered in a lush, vibrant carpet of green. The air is filled with the sweet scent of flowers and the distant hum of bees, creating a tranquil atmosphere that contrasts with the bizarre elements of the scene. A strange"
#         }
#     ],
#     "whole": [
#         {
#             "type": "easy",
#             "text": "A whole apple sits on a table."
#         },
#         {
#             "type": "medium",
#             "text": "A whole cake on a plate with a fork and knife."
#         },
#         {
#             "type": "hard",
#             "text": "A whole, round object floats in a vast, empty expanse, surrounded by a brilliant, shimmering light that seems to pulse with energy."
#         }
#     ],
#     "square": [
#         {
#             "type": "easy",
#             "text": "A square-shaped object."
#         },
#         {
#             "type": "medium",
#             "text": "A square-shaped mirror with a silver frame sitting on a wooden dresser."
#         },
#         {
#             "type": "hard",
#             "text": "A square-shaped cloud floats through the sky, casting a surreal and otherworldly shadow over the landscape below."
#         }
#     ],
#     "restoration": [
#         {
#             "type": "easy",
#             "text": "A man restoring a vintage car."
#         },
#         {
#             "type": "medium",
#             "text": "Restoration work in progress, with tools and materials surrounding the object being restored."
#         },
#         {
#             "type": "hard",
#             "text": "A majestic eagle, with wings outstretched, is perched on a glowing orb of light, surrounded by a kaleidoscope of colors and shapes that seem to be made of Restoration Hardware furniture."
#         }
#     ],
#     "covering": [
#         {
#             "type": "easy",
#             "text": "A blanket covering a person sleeping in bed."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy blanket covering a warm cup of cocoa."
#         },
#         {
#             "type": "hard",
#             "text": "A person wearing a covering made of clouds, floating through the sky and blending with the fluffy white clouds."
#         }
#     ],
#     "protest": [
#         {
#             "type": "easy",
#             "text": "Protesters holding signs in the street."
#         },
#         {
#             "type": "medium",
#             "text": "A protest gathering with people holding signs, wearing masks, and standing in a crowd."
#         },
#         {
#             "type": "hard",
#             "text": "A protest of kaleidoscopic flowers, with each petal glowing with a different color, as the crowd stands in solidarity with a cause that transcends time and space."
#         }
#     ],
#     "existence": [
#         {
#             "type": "easy",
#             "text": "Existence in all its forms, from the microscopic to the cosmic."
#         },
#         {
#             "type": "medium",
#             "text": "A person walking in a park with trees and flowers around, symbolizing the concept of existence."
#         },
#         {
#             "type": "hard",
#             "text": "A man exists in a world where the very concept of existence is questioned and debated. As he walks through the city, he sees people arguing about whether they truly exist or not. He wonders if he too is just an illusion, a product of his own mind. As he looks around, he sees objects and beings that"
#         }
#     ],
#     "props": [
#         {
#             "type": "easy",
#             "text": "A stage set with various props scattered around."
#         },
#         {
#             "type": "medium",
#             "text": "A set of vintage props, including antique books, old photographs, and decorative trinkets, sitting on a wooden table."
#         },
#         {
#             "type": "hard",
#             "text": "In a dimly lit room, a mysterious man stands in front of a tall, ornate mirror. His eyes, filled with the remnants of his past, reflect the faint glow of the nearby candle. The man is surrounded by an array of strange and intricate objects, each one holding a story of its own. The"
#         }
#     ],
#     "substance": [
#         {
#             "type": "easy",
#             "text": "A drop of liquid with a brownish hue."
#         },
#         {
#             "type": "medium",
#             "text": "A person holding a vial of clear liquid substance surrounded by other laboratory equipment such as a pipette, test tubes, and a microscope."
#         },
#         {
#             "type": "hard",
#             "text": "A substance so pure that it can melt the very stars."
#         }
#     ],
#     "medium": [
#         {
#             "type": "easy",
#             "text": "A medium-sized dog playing in a park."
#         },
#         {
#             "type": "medium",
#             "text": "A medium-sized dog is sitting on a cozy sofa with a plush stuffed animal nearby."
#         },
#         {
#             "type": "hard",
#             "text": "A medium-sized, glowing butterfly flutters through a surreal landscape, casting an otherworldly light on the surroundings."
#         }
#     ],
#     "jelly": [
#         {
#             "type": "easy",
#             "text": "A close-up of a bright, gooey jelly bean with its vibrant colors and sticky texture."
#         },
#         {
#             "type": "medium",
#             "text": "A jar of colorful jelly with a spoon and a stack of toast nearby."
#         },
#         {
#             "type": "hard",
#             "text": "A giant, squishy jellyfish with eyes made of sparkling sugar cubes floats lazily in a pool of shimmering, purple liquid, surrounded by floating, colorful jellyfish-shaped balloons and a rainbow-colored jellyfish-shaped cake."
#         }
#     ],
#     "keepsake": [
#         {
#             "type": "easy",
#             "text": "A small box filled with memories sits on a wooden shelf, a treasured keepsake of a loved one."
#         },
#         {
#             "type": "medium",
#             "text": "An old, weathered wooden box filled with cherished memories and family heirlooms, including a worn photograph, a small keepsake dish, and a collection of antique coins."
#         },
#         {
#             "type": "hard",
# ...
#             "text": "A marker, specifically a black marker, is lying on a wooden desk with a stack of papers nearby and a red pen resting beside it."
#         },
#         {
#             "type": "hard",
#             "text": "A marker with a face, arms, and legs stands in a room filled with colorful, floating shapes. The marker seems to be in the middle of painting the walls with vibrant strokes, creating a surreal and dreamlike atmosphere."
#         }
#     ],
#     "sphere": [
#         {
#             "type": "easy",
#             "text": "A single sphere is floating in the air."
#         },
#         {
#             "type": "medium",
#             "text": "Sphere, ball, round object, circle, ball game, sports equipment, toy, decoration, sculpture, celestial body, art piece, mathematics concept, geometry figure, abstract shape, futuristic design, sci-fi object, space concept, fantasy element, virtual reality, computer graphics, video game, digital art, 3D"
#         },
#         {
#             "type": "hard",
#             "text": "A sphere-shaped city with towering buildings made of glass and metal, floating in the sky like a giant marble."
#         }
#     ],
#     "fixture": [
#         {
#             "type": "easy",
#             "text": "The dimly lit room was illuminated by a single, antique-looking chandelier that served as a decorative fixture."
#         },
#         {
#             "type": "medium",
#             "text": "A modern bathroom with a sleek white vanity featuring a built-in sink and a stylish chrome faucet. The room is illuminated by a contemporary chandelier with intricate geometric patterns, casting a warm glow over the space."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal image featuring a glowing, anthropomorphic light fixture with intricate designs on its surface, casting a warm, otherworldly glow in a dimly-lit room."
#         }
#     ],
#     "strip": [
#         {
#             "type": "easy",
#             "text": "A long, thin strip of fabric lies on a table."
#         },
#         {
#             "type": "medium",
#             "text": "A strip of colorful confetti flying through the air with balloons and streamers in the background."
#         },
#         {
#             "type": "hard",
#             "text": "A woman with a golden hair is standing in the middle of a desert, holding a strip of paper with a complex mathematical equation written on it. Suddenly, the equation starts to glow and the woman begins to levitate, as if she's being pulled by the power of the equation."
#         }
#     ],
#     "chemistry": [
#         {
#             "type": "easy",
#             "text": "A laboratory filled with equipment and beakers for conducting chemistry experiments."
#         },
#         {
#             "type": "medium",
#             "text": "A chemistry lab filled with various equipment and tools, including beakers, test tubes, and a balance, with a laptop displaying a chemistry experiment in progress."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where chemistry governs everything, a group of scientists discovers a strange, glowing object that can manipulate matter at will. As they study its properties, they realize that it is not just a tool for scientific experimentation, but a powerful force that could alter the very fabric of reality. But as they delve deeper into"
#         }
#     ],
#     "marijuana": [
#         {
#             "type": "easy",
#             "text": "A small joint of marijuana sits on a wooden table."
#         },
#         {
#             "type": "medium",
#             "text": "A young man smoking a joint with a bong in the background."
#         },
#         {
#             "type": "hard",
#             "text": "In a dream-like landscape, a field of marijuana plants stretches out as far as the eye can see, with the sun setting behind a rainbow of colors."
#         }
#     ],
#     "buttons": [
#         {
#             "type": "easy",
#             "text": "A close-up of a white button on a dark background."
#         },
#         {
#             "type": "medium",
#             "text": "Buttons can be found on electronic devices such as smartphones, computers, and gaming consoles. They can also be found on clothing and accessories such as jackets, hats, and shoes. Buttons are often used to control various functions and settings on these items, such as volume, brightness, and color options. They can also be used"
#         },
#         {
#             "type": "hard",
#             "text": "A world where every surface is covered in buttons, and they have the power to come to life and take over the world."
#         }
#     ],
#     "serum": [
#         {
#             "type": "easy",
#             "text": "A small bottle of facial serum sits on a wooden table, ready to be applied to the skin for its moisturizing and nourishing benefits."
#         },
#         {
#             "type": "medium",
#             "text": "A serum bottle sits on a wooden table, surrounded by a pile of books, a vase of flowers, and a small glass of water."
#         },
#         {
#             "type": "hard",
#             "text": "A serpent with a glass eye coiled around a vial of glowing serum, as if it had just swallowed the elixir of eternal youth."
#         }
#     ],
#     "chalk": [
#         {
#             "type": "easy",
#             "text": "A blackboard with a piece of chalk in hand."
#         },
#         {
#             "type": "medium",
#             "text": "A chalkboard with a piece of chalk resting on it, surrounded by other chalkboards and a stack of books."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where colors come to life, a giant chalkboard looms over a bustling city filled with vibrant, dancing shapes. As the sun sets, a lone chalk figure emerges from the depths of the board, its body composed of soft, pastel colors. It walks the streets, leaving behind trails of its own"
#         }
#     ],
#     "thread": [
#         {
#             "type": "easy",
#             "text": "A tangled spool of thread lies on a wooden table."
#         },
#         {
#             "type": "medium",
#             "text": "A spool of thread sits on a sewing table, alongside a needle and scissors, ready for crafting or sewing projects."
#         },
#         {
#             "type": "hard",
#             "text": "A thread of light weaves through a dreamlike landscape, where flowers grow from clouds and mountains are made of cotton candy."
#         }
#     ],
#     "enamel": [
#         {
#             "type": "easy",
#             "text": "A piece of shiny enamel with intricate designs."
#         },
#         {
#             "type": "medium",
#             "text": "A piece of jewelry with an intricate enamel design surrounded by sparkling diamonds and set in a delicate gold setting."
#         },
#         {
#             "type": "hard",
#             "text": "A world made entirely of shiny, iridescent enamel where everything sparkles and shimmers in the light, from the towering buildings to the smallest specks of dust in the air."
#         }
#     ],
#     "block": [
#         {
#             "type": "easy",
#             "text": "An abstract sculpture made of blocks of wood."
#         },
#         {
#             "type": "medium",
#             "text": "A block of wood resting on a table surrounded by scattered tools and a pile of books."
#         },
#         {
#             "type": "hard",
#             "text": "A giant block of solid gold was found in the middle of a dense forest, surrounded by a mysterious fog."
#         }
#     ],
#     "article": [
#         {
#             "type": "easy",
#             "text": "Article on the table."
#         },
#         {
#             "type": "medium",
#             "text": "A well-written article, accompanied by a beautiful illustration and insightful graphs, discusses the latest research findings in the field of quantum physics."
#         },
#         {
#             "type": "hard",
#             "text": "A kaleidoscope of colors and patterns swirled around a single article of clothing, creating a mesmerizing display of light and movement."
#         }
#     ],
#     "ornament": [
#         {
#             "type": "easy",
#             "text": "A beautifully decorated Christmas tree adorned with various ornaments."
#         },
#         {
#             "type": "medium",
#             "text": "A beautifully crafted ornament sits elegantly on a table, surrounded by a collection of other decorative items such as candles, flowers, and small figurines."
#         },
#         {
#             "type": "hard",
#             "text": "A mysterious forest where ornaments come to life and dance under the moonlight."
#         }
#     ],
#     "snake": [
#         {
#             "type": "easy",
#             "text": "A snake slithers gracefully through the grass, its scales shimmering in the sunlight."
#         },
#         {
#             "type": "medium",
#             "text": "A snake slithers through a dense forest, surrounded by lush greenery and tall trees."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where snakes have the ability to speak and understand human language, a snake with a human-like face sits in a library, surrounded by books and a telescope, observing the stars and contemplating the mysteries of the universe."
#         }
#     ],
#     "earth": [
#         {
#             "type": "easy",
#             "text": "A vast and beautiful view of the Earth from space, showcasing its diverse landscapes and vibrant colors."
#         },
#         {
#             "type": "medium",
#             "text": "A vibrant and lush landscape with verdant trees, sparkling rivers, and towering mountains in the background, with the Earth as the backdrop."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike landscape, the Earth is a glowing, iridescent orb, suspended in the void, surrounded by a kaleidoscope of colors and shapes that seem to shift and twist in the eternal present. The surface of the planet is covered in a tapestry of strange, otherworldly vegetation and flora,"
#         }
#     ],
#     "sheet": [
#         {
#             "type": "easy",
#             "text": "A stack of white sheets is neatly folded on a wooden table."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy blanket and a book."
#         },
#         {
#             "type": "hard",
#             "text": "A sheet of gold stretches across the sky, shining bright as a sunset, with clouds shaped like sheets billowing in the background."
#         }
#     ],
#     "carpet": [
#         {
#             "type": "easy",
#             "text": "A cozy living room with a plush carpet underfoot."
#         },
#         {
#             "type": "medium",
#             "text": "A cozy living room featuring a plush carpet with a warm and inviting atmosphere, accompanied by comfortable furniture and cozy lighting."
#         },
#         {
#             "type": "hard",
#             "text": "A carpet with a pattern of floating clouds, where the colors and shapes seem to shift and change as you walk over it, leading to a distant, surreal landscape."
#         }
#     ],
#     "ink": [
#         {
#             "type": "easy",
#             "text": "A black ink bottle sits on a wooden table."
#         },
#         {
#             "type": "medium",
#             "text": "A bottle of ink sitting on a desk next to a blank sheet of paper."
#         },
#         {
#             "type": "hard",
#             "text": "A group of ink-splattered rabbits hopped through a field of swirling ink clouds, their eyes glowing with a deep, mysterious light."
#         }
#     ],
#     "web": [
#         {
#             "type": "easy",
#             "text": "A web of intricate lines and shapes spanning across a digital screen."
#         },
#         {
#             "type": "medium",
#             "text": "A web is a network of connected documents, pages, or resources on the internet, often displayed in a hyperlinked format. It can be accessed through a web browser, allowing users to navigate from one page to another, and from one website to another. A web can be used for various purposes, such as gathering information"
#         },
#         {
#             "type": "hard",
#             "text": "In a world where the internet has taken over, a man discovers a portal that leads to a world where the web is a living, breathing entity."
#         }
#     ],
#     "moon": [
#         {
#             "type": "easy",
#             "text": "The moon shines brightly in the night sky."
#         },
#         {
#             "type": "medium",
#             "text": "A glowing full moon shines brightly in the night sky, casting a warm glow on the surrounding clouds and stars."
#         },
#         {
#             "type": "hard",
#             "text": "In a dreamlike landscape, a shimmering moon casts a mystical glow upon a field of floating flowers, as a unicorn gallops through the grass with a glowing apple in its mouth."
#         }
#     ],
#     "ribbon": [
#         {
#             "type": "easy",
#             "text": "A beautiful ribbon gracefully curled around a gift."
#         },
#         {
#             "type": "medium",
#             "text": "A vibrant ribbon gracefully flowing through a lush, green meadow, accompanied by the gentle hum of bees and the soft rustle of leaves."
#         },
#         {
#             "type": "hard",
#             "text": "In a world where ribbons have a mind of their own, a ribbon dances through a field of wildflowers, its colors changing with each gust of wind."
#         }
#     ],
#     "fabric": [
#         {
#             "type": "easy",
#             "text": "A vibrant patchwork quilt made of various pieces of colorful fabric."
#         },
#         {
#             "type": "medium",
#             "text": "A bolt of fabric sits alongside a sewing machine, ready to be transformed into a new garment. Nearby, a spool of thread and a pair of scissors are neatly arranged, waiting to be used for the sewing project."
#         },
#         {
#             "type": "hard",
#             "text": "A fabric-covered chair with no back or legs, floating in a room with no walls or floor."
#         }
#     ],
#     "sample": [
#         {
#             "type": "easy",
#             "text": "Sample"
#         },
#         {
#             "type": "medium",
#             "text": "Sample next to a magnifying glass and a slide of a plant cell."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal landscape where the horizon is dotted with small, metallic sculptures that resemble samples from a laboratory. The sky is a iridescent blue and the ground is covered in a layer of shimmering, liquid silver. The air is filled with a strange, sweet smell that lingers in the nostrils."
#         }
#     ],
#     "film": [
#         {
#             "type": "easy",
#             "text": "A film reel is spooling in a projector, casting a flickering light on the nearby wall."
#         },
#         {
#             "type": "medium",
#             "text": "A film projector with a roll of film and a screen in the background."
#         },
#         {
#             "type": "hard",
#             "text": "A film reel is seen floating in a strange, colorful dreamscape, with images of past movies projected onto the surrounding environment."
#         }
#     ],
#     "button": [
#         {
#             "type": "easy",
#             "text": "A button is pressing down on a surface."
#         },
#         {
#             "type": "medium",
#             "text": "A shiny button is surrounded by a pile of coins and a key."
#         },
#         {
#             "type": "hard",
#             "text": "A button floats in mid-air, surrounded by a surreal array of colors and shapes that defy explanation."
#         }
#     ],
#     "cover": [
#         {
#             "type": "easy",
#             "text": "A person wearing a raincoat."
#         },
#         {
#             "type": "medium",
#             "text": "A book cover lies on a table next to a cup of coffee and a stack of papers."
#         },
#         {
#             "type": "hard",
#             "text": "A surreal image of a giant, floating cover with eyes and arms, drifting through a colorful, distorted landscape."
#         }
#     ]
# }
